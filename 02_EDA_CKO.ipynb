# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix, andrews_curves, parallel_coordinates

pd.set_option('display.max_columns', 54)

# %%
# reading in the cleaned supply chain csv-

df = pd.read_csv('./data/ship_clean.csv')

# %%
df.head()
# Out:
#        type  actual_ship_days  estimated_ship_days   delivery_status  \
# 0     DEBIT                 3                    4  Advance shipping
# 1  TRANSFER                 5                    4     Late delivery
# 2      CASH                 4                    4  Shipping on time
# 3     DEBIT                 3                    4  Advance shipping
# 4   PAYMENT                 2                    4  Advance shipping
#
#    late_delivery_risk  category_id   category_name customer_city  customer_id  \
# 0                   0           73  Sporting Goods        Caguas        20755
# 1                   1           73  Sporting Goods        Caguas        19492
# 2                   0           73  Sporting Goods      San Jose        19491
# 3                   0           73  Sporting Goods   Los Angeles        19490
# 4                   0           73  Sporting Goods        Caguas        19489
#
#   customer_segment customer_state  customer_zipcode department_name  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   type                      180519 non-null  object
#  1   actual_ship_days          180519 non-null  int64
#  2   estimated_ship_days       180519 non-null  int64
#  3   delivery_status           180519 non-null  object
#  4   late_delivery_risk        180519 non-null  int64
#  5   category_id               180519 non-null  int64
#  6   category_name             180519 non-null  object
#  7   customer_city             180519 non-null  object
#  8   customer_id               180519 non-null  int64
#  9   customer_segment          180519 non-null  object
#  10  customer_state            180519 non-null  object
#  11  customer_zipcode          180516 non-null  float64
#  12  department_name           180519 non-null  object
# ...

# %%
df.delivery_status.unique()
# Out:
# array(['Advance shipping', 'Late delivery', 'Shipping on time',
#        'Shipping canceled'], dtype=object)

# %%
andrews_curves(df, 'delivery_status');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-d9cd7396ea58> in <module>
# ----> 1 andrews_curves(df, 'delivery_status');
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/plotting/_misc.py in andrews_curves(frame, class_column, ax, samples, color, colormap, **kwargs)
#     269     """
#     270     plot_backend = _get_plot_backend("matplotlib")
# --> 271     return plot_backend.andrews_curves(
#     272         frame=frame,
#     273         class_column=class_column,
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/misc.py in andrews_curves(frame, class_column, ax, samples, color, colormap, **kwds)
#     276         row = df.iloc[i].values
#     277         f = function(row)
# --> 278         y = f(t)
#     279         kls = class_col.iat[i]
#     280         label = pprint_thing(kls)
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('DataCoSupplyChainDataset.csv', encoding = 'unicode_escape')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
#  12  Customer Fname                 180519 non-null  object
#  13  Customer Id                    180519 non-null  int64
#  14  Customer Lname                 180511 non-null  object
#  15  Customer Password              180519 non-null  object
#  16  Customer Segment               180519 non-null  object
#  17  Customer State                 180519 non-null  object
#  18  Customer Street                180519 non-null  object
#  19  Customer Zipcode               180516 non-null  float64
#  20  Department Id                  180519 non-null  int64
#  21  Department Name                180519 non-null  object
#  22  Latitude                       180519 non-null  float64
#  23  Longitude                      180519 non-null  float64
#  24  Market                         180519 non-null  object
#  25  Order City                     180519 non-null  object
#  26  Order Country                  180519 non-null  object
#  27  Order Customer Id              180519 non-null  int64
#  28  order date (DateOrders)        180519 non-null  object
#  29  Order Id                       180519 non-null  int64
#  30  Order Item Cardprod Id         180519 non-null  int64
#  31  Order Item Discount            180519 non-null  float64
#  32  Order Item Discount Rate       180519 non-null  float64
#  33  Order Item Id                  180519 non-null  int64
#  34  Order Item Product Price       180519 non-null  float64
#  35  Order Item Profit Ratio        180519 non-null  float64
#  36  Order Item Quantity            180519 non-null  int64
#  37  Sales                          180519 non-null  float64
#  38  Order Item Total               180519 non-null  float64
#  39  Order Profit Per Order         180519 non-null  float64
#  40  Order Region                   180519 non-null  object
#  41  Order State                    180519 non-null  object
#  42  Order Status                   180519 non-null  object
#  43  Order Zipcode                  24840 non-null   float64
#  44  Product Card Id                180519 non-null  int64
#  45  Product Category Id            180519 non-null  int64
#  46  Product Description            0 non-null       float64
#  47  Product Image                  180519 non-null  object
#  48  Product Name                   180519 non-null  object
#  49  Product Price                  180519 non-null  float64
#  50  Product Status                 180519 non-null  int64
#  51  shipping date (DateOrders)     180519 non-null  object
#  52  Shipping Mode                  180519 non-null  object
# dtypes: float64(15), int64(14), object(24)
# memory usage: 73.0+ MB

# %%
pd.set_option('display.max_columns', 54)

# %%
df.loc[df['Type'] == 'CASH']
# Out:
#         Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 2       CASH                         4                              4
# 8       CASH                         3                              2
# 9       CASH                         2                              1
# 17      CASH                         2                              1
# 36      CASH                         2                              1
# ...      ...                       ...                            ...
# 180467  CASH                         2                              1
# 180496  CASH                         2                              4
# 180498  CASH                         3                              4
# 180504  CASH                         3                              4
# 180514  CASH                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# 2             -247.779999          309.720001  Shipping on time
# 8              133.720001          278.589996     Late delivery
# 9              132.149994          275.309998     Late delivery
# 17              23.840000          317.920013     Late delivery
# 36             151.029999          314.640015     Late delivery
# ...                   ...                 ...               ...
# 180467          27.900000          371.980011     Late delivery
# 180496         145.190002          399.980011  Advance shipping
# 180498        -337.100006          391.980011  Advance shipping
# 180504          32.029999          363.980011  Advance shipping
# 180514          40.000000          399.980011  Shipping on time
#
#         Late_delivery_risk  Category Id   Category Name  Customer City  \
# 2                        0           73  Sporting Goods       San Jose
# 8                        1           73  Sporting Goods         Caguas
# 9                        1           73  Sporting Goods      San Ramon
# 17                       1           73  Sporting Goods      Paramount
# 36                       1           73  Sporting Goods       Carlisle
# ...                    ...          ...             ...            ...
# 180467                   1           45         Fishing  Panorama City
# 180496                   0           45         Fishing     Costa Mesa
# 180498                   0           45         Fishing    Lindenhurst
# 180504                   0           45         Fishing         Caguas
# 180514                   0           45         Fishing       Brooklyn
#
#        Customer Country Customer Email Customer Fname  Customer Id  \
# 2               EE. UU.      XXXXXXXXX        Gillian        19491
# 8           Puerto Rico      XXXXXXXXX        Nichole        19485
# 9               EE. UU.      XXXXXXXXX          Oprah        19484
# 17              EE. UU.      XXXXXXXXX          Ciara        19476
# 36              EE. UU.      XXXXXXXXX          Libby        19457
# ...                 ...            ...            ...          ...
# 180467          EE. UU.      XXXXXXXXX           Mary         4164
# 180496          EE. UU.      XXXXXXXXX           Mary         2555
# 180498          EE. UU.      XXXXXXXXX           Mary         2642
# 180504      Puerto Rico      XXXXXXXXX           Ryan         8183
# 180514          EE. UU.      XXXXXXXXX          Maria         1005
#
#        Customer Lname Customer Password Customer Segment Customer State  \
# 2           Maldonado         XXXXXXXXX         Consumer             CA
# 8               Olsen         XXXXXXXXX        Corporate             PR
# 9            Delacruz         XXXXXXXXX        Corporate             CA
# 17               Bird         XXXXXXXXX        Corporate             CA
# 36               Bray         XXXXXXXXX        Corporate             PA
# ...               ...               ...              ...            ...
# 180467          Smith         XXXXXXXXX         Consumer             CA
# 180496           Long         XXXXXXXXX         Consumer             CA
# 180498          Gould         XXXXXXXXX         Consumer             NY
# 180504          Giles         XXXXXXXXX        Corporate             PR
# 180514       Peterson         XXXXXXXXX      Home Office             NY
#
#                  Customer Street  Customer Zipcode  Department Id  \
# 2           8510 Round Bear Gate           95125.0              2
# 8               2051 Dusty Route             725.0              2
# 9        9139 Blue Blossom Court           94583.0              2
# 17             7787 Lazy Corners           90723.0              2
# 36         6127 Dewy Goose Downs           17013.0              2
# ...                          ...               ...            ...
# 180467          9767 Merry Manor           91402.0              7
# 180496           1022 Dusty Glen           92626.0              7
# 180498    1812 Sunny River Wharf           11757.0              7
# 180504  2137 Silver Brook Square             725.0              7
# 180514          1322 Broad Glade           11207.0              7
#
#        Department Name   Latitude   Longitude        Market Order City  \
# 2              Fitness  37.292233 -121.881279  Pacific Asia    Bikaner
# 8              Fitness  18.233223  -66.037056  Pacific Asia  Guangzhou
# 9              Fitness  37.773991 -121.966629  Pacific Asia  Guangzhou
# 17             Fitness  33.898693 -118.174560  Pacific Asia   Jabalpur
# 36             Fitness  40.031719  -76.877098  Pacific Asia      Hubli
# ...                ...        ...         ...           ...        ...
# 180467        Fan Shop  35.406689 -118.895302  Pacific Asia     Nagpur
# 180496        Fan Shop  33.676708 -117.921905  Pacific Asia   Shanghái
# 180498        Fan Shop  40.686657  -73.375534  Pacific Asia  Palembang
# 180504        Fan Shop  18.240986  -66.370552  Pacific Asia   Canberra
# 180514        Fan Shop  40.640930  -73.942711  Pacific Asia   Shanghái
#
#        Order Country  Order Customer Id order date (DateOrders)  Order Id  \
# 2              India              19491         1/13/2018 12:06     75938
# 8              China              19485         1/13/2018 10:00     75932
# 9              China              19484          1/13/2018 9:39     75931
# 17             India              19476          1/13/2018 6:51     75923
# 36             India              19457          1/13/2018 0:12     75904
# ...              ...                ...                     ...       ...
# 180467         India               4164         1/18/2016 19:05     26224
# 180496         China               2555         1/16/2016 22:14     26096
# 180498     Indonesia               2642         1/16/2016 19:05     26087
# 180504     Australia               8183         1/16/2016 13:49     26072
# 180514         China               1005          1/16/2016 3:40     26043
#
#         Order Item Cardprod Id  Order Item Discount  Order Item Discount Rate  \
# 2                         1360            18.030001                      0.06
# 8                         1360            49.160000                      0.15
# 9                         1360            52.439999                      0.16
# 17                        1360             9.830000                      0.03
# 36                        1360            13.110000                      0.04
# ...                        ...                  ...                       ...
# 180467                    1004            28.000000                      0.07
# 180496                    1004             0.000000                      0.00
# 180498                    1004             8.000000                      0.02
# 180504                    1004            36.000000                      0.09
# 180514                    1004             0.000000                      0.00
#
#         Order Item Id  Order Item Product Price  Order Item Profit Ratio  \
# 2              179253                327.750000                    -0.80
# 8              179247                327.750000                     0.48
# 9              179246                327.750000                     0.48
# 17             179238                327.750000                     0.08
# 36             179219                327.750000                     0.48
# ...               ...                       ...                      ...
# 180467          65639                399.980011                     0.08
# 180496          65326                399.980011                     0.36
# 180498          65296                399.980011                    -0.86
# 180504          65258                399.980011                     0.09
# 180514          65177                399.980011                     0.10
#
#         Order Item Quantity       Sales  Order Item Total  \
# 2                         1  327.750000        309.720001
# 8                         1  327.750000        278.589996
# 9                         1  327.750000        275.309998
# 17                        1  327.750000        317.920013
# 36                        1  327.750000        314.640015
# ...                     ...         ...               ...
# 180467                    1  399.980011        371.980011
# 180496                    1  399.980011        399.980011
# 180498                    1  399.980011        391.980011
# 180504                    1  399.980011        363.980011
# 180514                    1  399.980011        399.980011
#
#         Order Profit Per Order    Order Region  \
# 2                  -247.779999      South Asia
# 8                   133.720001    Eastern Asia
# 9                   132.149994    Eastern Asia
# 17                   23.840000      South Asia
# 36                  151.029999      South Asia
# ...                        ...             ...
# 180467               27.900000      South Asia
# 180496              145.190002    Eastern Asia
# 180498             -337.100006  Southeast Asia
# 180504               32.029999         Oceania
# 180514               40.000000    Eastern Asia
#
#                                  Order State Order Status  Order Zipcode  \
# 2                                   Rajastán       CLOSED            NaN
# 8                                  Guangdong       CLOSED            NaN
# 9                                  Guangdong       CLOSED            NaN
# 17                            Madhya Pradesh       CLOSED            NaN
# 36                                 Karnataka       CLOSED            NaN
# ...                                      ...          ...            ...
# 180467                           Maharashtra       CLOSED            NaN
# 180496                              Shanghái       CLOSED            NaN
# 180498                    Sumatra Meridional       CLOSED            NaN
# 180504  Territorio de la Capital Australiana       CLOSED            NaN
# 180514                              Shanghái       CLOSED            NaN
#
#         Product Card Id  Product Category Id  Product Description  \
# 2                  1360                   73                  NaN
# 8                  1360                   73                  NaN
# 9                  1360                   73                  NaN
# 17                 1360                   73                  NaN
# 36                 1360                   73                  NaN
# ...                 ...                  ...                  ...
# 180467             1004                   45                  NaN
# 180496             1004                   45                  NaN
# 180498             1004                   45                  NaN
# 180504             1004                   45                  NaN
# 180514             1004                   45                  NaN
#
#                                             Product Image  \
# 2            http://images.acmesports.sports/Smart+watch
# 8            http://images.acmesports.sports/Smart+watch
# 9            http://images.acmesports.sports/Smart+watch
# 17           http://images.acmesports.sports/Smart+watch
# 36           http://images.acmesports.sports/Smart+watch
# ...                                                   ...
# 180467  http://images.acmesports.sports/Field+%26+Stre...
# 180496  http://images.acmesports.sports/Field+%26+Stre...
# 180498  http://images.acmesports.sports/Field+%26+Stre...
# 180504  http://images.acmesports.sports/Field+%26+Stre...
# 180514  http://images.acmesports.sports/Field+%26+Stre...
#
#                                      Product Name  Product Price  \
# 2                                    Smart watch      327.750000
# 8                                    Smart watch      327.750000
# 9                                    Smart watch      327.750000
# 17                                   Smart watch      327.750000
# 36                                   Smart watch      327.750000
# ...                                           ...            ...
# 180467  Field & Stream Sportsman 16 Gun Fire Safe     399.980011
# 180496  Field & Stream Sportsman 16 Gun Fire Safe     399.980011
# 180498  Field & Stream Sportsman 16 Gun Fire Safe     399.980011
# 180504  Field & Stream Sportsman 16 Gun Fire Safe     399.980011
# 180514  Field & Stream Sportsman 16 Gun Fire Safe     399.980011
#
#         Product Status shipping date (DateOrders)   Shipping Mode
# 2                    0            1/17/2018 12:06  Standard Class
# 8                    0            1/16/2018 10:00    Second Class
# 9                    0             1/15/2018 9:39     First Class
# 17                   0             1/15/2018 6:51     First Class
# 36                   0             1/15/2018 0:12     First Class
# ...                ...                        ...             ...
# 180467               0            1/20/2016 19:05     First Class
# 180496               0            1/18/2016 22:14  Standard Class
# 180498               0            1/19/2016 19:05  Standard Class
# 180504               0            1/19/2016 13:49  Standard Class
# 180514               0             1/20/2016 3:40  Standard Class
#
# [19616 rows x 53 columns]

# %%
df['Order Status'].value_counts()
# Out:
# COMPLETE           59491
# PENDING_PAYMENT    39832
# PROCESSING         21902
# PENDING            20227
# CLOSED             19616
# ON_HOLD             9804
# SUSPECTED_FRAUD     4062
# CANCELED            3692
# PAYMENT_REVIEW      1893
# Name: Order Status, dtype: int64

# %%
df['Type'].value_counts()
# Out:
# DEBIT       69295
# TRANSFER    49883
# PAYMENT     41725
# CASH        19616
# Name: Type, dtype: int64

# %%
df['Sales'][25700]
# Out:
# 239.96000669999998

# %%
df['Sales per customer']
# Out:
# 0         314.640015
# 1         311.359985
# 2         309.720001
# 3         304.809998
# 4         298.250000
#              ...
# 180514    399.980011
# 180515    395.980011
# 180516    391.980011
# 180517    387.980011
# 180518    383.980011
# Name: Sales per customer, Length: 180519, dtype: float64

# %%
# remove from DataFrame

# df['Product Status'].value_counts()
# df['Product Description'].value_counts()
# df['Customer Email'].value_counts()
df['Order Id'].value_counts()
# Out:
# 30397    5
# 16203    5
# 42806    5
# 49302    5
# 60278    5
#         ..
# 41140    1
# 34752    1
# 75636    1
# 73587    1
# 2049     1
# Name: Order Id, Length: 65752, dtype: int64

# %%
df['Department Name'].value_counts()
# Out:
# Fan Shop              66861
# Apparel               48998
# Golf                  33220
# Footwear              14525
# Outdoors               9686
# Fitness                2479
# Discs Shop             2026
# Technology             1465
# Pet Shop                492
# Book Shop               405
# Health and Beauty       362
# Name: Department Name, dtype: int64

# %%
df[''].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'State'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-71768c573960> in <module>
# ----> 1 df['State'].value_counts()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'State'

# %%
df['Order State'].value_counts()
# df['Delivery Status'].value_counts()
# df['Late_delivery_risk'].value_counts()
# Order Zipcode
# Out:
# Inglaterra                     6722
# California                     4966
# Isla de Francia                4580
# Renania del Norte-Westfalia    3303
# San Salvador                   3055
#                                ...
# Kabarole                          1
# Terranova                         1
# Tottori                           1
# Suceava                           1
# Mashonalandia Occidental          1
# Name: Order State, Length: 1089, dtype: int64

# %%
df['Department Id'].value_counts()
# Out:
# 7     66861
# 4     48998
# 5     33220
# 3     14525
# 6      9686
# 2      2479
# 9      2026
# 10     1465
# 11      492
# 8       405
# 12      362
# Name: Department Id, dtype: int64

# %%
df['Product Name'].value_counts().head(20)
# Out:
# Perfect Fitness Perfect Rip Deck                 24515
# Nike Men's CJ Elite 2 TD Football Cleat          22246
# Nike Men's Dri-FIT Victory Golf Polo             21035
# O'Brien Men's Neoprene Life Vest                 19298
# Field & Stream Sportsman 16 Gun Fire Safe        17325
# Pelican Sunstream 100 Kayak                      15500
# Diamondback Women's Serene Classic Comfort Bi    13729
# Nike Men's Free 5.0+ Running Shoe                12169
# Under Armour Girls' Toddler Spine Surge Runni    10617
# Fighting video games                               838
# Children's heaters                                 652
# Summer dresses                                     650
# Web Camera                                         592
# Toys                                               529
# Adult dog supplies                                 492
# Lawn mower                                         484
# Porcelain crafts                                   484
# DVDs                                               483
# Dell Laptop                                        442
# Rock music                                         434
# Name: Product Name, dtype: int64

# %%
df['Customer Id'].value_counts()
# Out:
# 5654     47
# 5004     45
# 10591    45
# 5715     44
# 3708     44
#          ..
# 13486     1
# 17887     1
# 15952     1
# 13905     1
# 14375     1
# Name: Customer Id, Length: 20652, dtype: int64

# %%
df['Customer Segment'].value_counts()
# Out:
# Consumer       93504
# Corporate      54789
# Home Office    32226
# Name: Customer Segment, dtype: int64
